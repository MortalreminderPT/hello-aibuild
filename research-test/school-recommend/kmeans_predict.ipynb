# %%
import torch
import pickle
from kmeans_pytorch import kmeans_predict
from utils import read, process, normalize

# %%
training_results = {}

with open('kmeans_model.pkl', 'rb') as file:
    training_results = pickle.load(file)

school = {
    'lat': -35,
    'lon': 117,
    'num_student': 977,
    'atar': 2000,
    'icsea': 1000,
}

means = training_results['means']
std_dev = training_results['std_dev']
centers = training_results['centers']
labels = training_results['labels']

schools = [school, school]
predict_array = process(schools)
predict_array = normalize(
    predict_array, 
    means, 
    std_dev, 
    'means_filling'
)

predict_tensor = torch.tensor(predict_array)

cluster_ids_y = kmeans_predict(predict_tensor, centers, 'euclidean')

school_list = read('./wa_secondary_schools.csv')
for i in range(labels.shape[0]):
    if cluster_ids_y[0] == labels[i]:
        print(labels[i], school_list[i])
# Out:
# [-5.11692093e-01  8.56222924e-01  8.92163665e-01 -4.49097068e-01
#   7.05739812e+02  9.99557252e+02  7.75741007e+01]
# 427.4300898319394
# predicting on cpu..
# tensor(4) {'name': "ALL SAINTS' COLLEGE", 'lat': -32.04946998, 'lon': 115.867023, 'num_student': 1354, 'atar': 86.35, 'icsea': 1154}
# tensor(4) {'name': 'APPLECROSS SENIOR HIGH SCHOOL', 'lat': -32.029376, 'lon': 115.83509, 'num_student': 1665, 'atar': 84.3, 'icsea': 1111}
# tensor(4) {'name': 'AQUINAS COLLEGE', 'lat': -32.02617519, 'lon': 115.8617538, 'num_student': 1312, 'atar': 85.85, 'icsea': 1023}
# tensor(4) {'name': 'ATWELL COLLEGE', 'lat': -32.14395682, 'lon': 115.8641462, 'num_student': 1418, 'atar': 64.05, 'icsea': 1012}
# tensor(4) {'name': 'AUSTRALIAN ISLAMIC COLLEGE - KEWDALE', 'lat': -31.97999061, 'lon': 115.9325273, 'num_student': 1729, 'atar': 72.55, 'icsea': 985}
# tensor(4) {'name': 'AUSTRALIND SENIOR HIGH SCHOOL', 'lat': -33.27665965, 'lon': 115.7284365, 'num_student': 1424, 'atar': 78.4, 'icsea': 977}
# tensor(4) {'name': 'BALDIVIS SECONDARY COLLEGE', 'lat': -32.334099, 'lon': 115.828418, 'num_student': 1657, 'atar': 60.45, 'icsea': 987}
# tensor(4) {'name': 'BALLAJURA COMMUNITY COLLEGE', 'lat': -31.84474671, 'lon': 115.8934345, 'num_student': 1216, 'atar': 62.5, 'icsea': 977}
# tensor(4) {'name': 'BUTLER COLLEGE', 'lat': -31.65166367, 'lon': 115.7087008, 'num_student': 1633, 'atar': 83.7, 'icsea': 993}
# tensor(4) {'name': 'BYFORD SECONDARY COLLEGE', 'lat': -32.22343162, 'lon': 116.0018793, 'num_student': 1444, 'atar': 68.0, 'icsea': 989}
# tensor(4) {'name': 'CANNING VALE COLLEGE', 'lat': -32.08291838, 'lon': 115.9227838, 'num_student': 1459, 'atar': 79.8, 'icsea': 1030}
# tensor(4) {'name': 'CAREY BAPTIST COLLEGE', 'lat': -32.11159158, 'lon': 115.9355423, 'num_student': 1429, 'atar': 80.3, 'icsea': 1097}
# tensor(4) {'name': 'CHISHOLM CATHOLIC COLLEGE', 'lat': -31.91151257, 'lon': 115.9005647, 'num_student': 1675, 'atar': 84.8, 'icsea': 1070}
# tensor(4) {'name': 'CHRIST CHURCH GRAMMAR SCHOOL', 'lat': -31.98546117, 'lon': 115.7769868, 'num_student': 1688, 'atar': 92.5, 'icsea': 1180}
# tensor(4) {'name': 'CORPUS CHRISTI COLLEGE', 'lat': -32.05699614, 'lon': 115.8429056, 'num_student': 1286, 'atar': 84.95, 'icsea': 1098}
# tensor(4) {'name': 'DUNCRAIG SENIOR HIGH SCHOOL', 'lat': -31.82190527, 'lon': 115.767131, 'num_student': 1621, 'atar': 84.5, 'icsea': 1073}
# tensor(4) {'name': 'ELLENBROOK SECONDARY COLLEGE', 'lat': -31.78554916, 'lon': 115.9642807, 'num_student': 1444, 'atar': 66.25, 'icsea': 986}
# tensor(4) {'name': 'EMMANUEL CATHOLIC COLLEGE', 'lat': -32.12857818, 'lon': 115.8400696, 'num_student': 1098, 'atar': 80.8, 'icsea': 1036}
# tensor(4) {'name': 'FREDERICK IRWIN ANGLICAN SCHOOL', 'lat': -32.50869435, 'lon': 115.7530802, 'num_student': 1592, 'atar': 79.65, 'icsea': 1088}
# tensor(4) {'name': 'GEORGIANA MOLLOY ANGLICAN SCHOOL', 'lat': -33.6606425, 'lon': 115.3815495, 'num_student': 1121, 'atar': 82.6, 'icsea': 1072}
# tensor(4) {'name': 'GREENWOOD COLLEGE', 'lat': -31.82628484, 'lon': 115.7914439, 'num_student': 1071, 'atar': 75.75, 'icsea': 1032}
# tensor(4) {'name': 'HALE SCHOOL', 'lat': -31.91232249, 'lon': 115.7837828, 'num_student': 1594, 'atar': 90.35, 'icsea': 1165}
# tensor(4) {'name': 'HALLS HEAD COLLEGE', 'lat': -32.55444963, 'lon': 115.6942404, 'num_student': 1399, 'atar': 69.95, 'icsea': 930}
# tensor(4) {'name': 'HARRISDALE SENIOR HIGH SCHOOL', 'lat': -32.127736, 'lon': 115.934521, 'num_student': 1258, 'atar': -1, 'icsea': 1041}
# tensor(4) {'name': 'HOLY CROSS COLLEGE', 'lat': -31.773097, 'lon': 115.973832, 'num_student': 1121, 'atar': 74.2, 'icsea': 1043}
# tensor(4) {'name': 'IONA PRESENTATION COLLEGE', 'lat': -32.00852636, 'lon': 115.7677349, 'num_student': 1190, 'atar': 87.8, 'icsea': 1124}
# tensor(4) {'name': 'JOHN FORREST SECONDARY COLLEGE', 'lat': -31.90416352, 'lon': 115.90089, 'num_student': 1114, 'atar': 78.7, 'icsea': 1025}
# tensor(4) {'name': 'JOHN SEPTIMUS ROE ANGLICAN COMMUNITY SCHOOL', 'lat': -31.85936631, 'lon': 115.8567055, 'num_student': 1727, 'atar': 84.0, 'icsea': 1070}
# tensor(4) {'name': 'JOHN XXIII COLLEGE', 'lat': -31.9599189, 'lon': 115.7847988, 'num_student': 1579, 'atar': 89.5, 'icsea': 1170}
# tensor(4) {'name': 'KALAMUNDA SENIOR HIGH SCHOOL', 'lat': -31.97788079, 'lon': 116.0561861, 'num_student': 1176, 'atar': 71.05, 'icsea': 1015}
# tensor(4) {'name': 'KARRATHA SENIOR HIGH SCHOOL', 'lat': -20.74695822, 'lon': 116.8241249, 'num_student': 1208, 'atar': 62.8, 'icsea': 944}
# tensor(4) {'name': 'KELMSCOTT SENIOR HIGH SCHOOL', 'lat': -32.12147619, 'lon': 116.0110534, 'num_student': 1295, 'atar': 69.7, 'icsea': 983}
# tensor(4) {'name': 'KENNEDY BAPTIST COLLEGE', 'lat': -32.073356, 'lon': 115.829647, 'num_student': 1160, 'atar': 88.95, 'icsea': 1097}
# tensor(4) {'name': 'KOLBE CATHOLIC COLLEGE', 'lat': -32.27997384, 'lon': 115.7539727, 'num_student': 1160, 'atar': 74.25, 'icsea': 1046}
# tensor(4) {'name': 'LA SALLE COLLEGE', 'lat': -31.87856979, 'lon': 116.004411, 'num_student': 1392, 'atar': 81.25, 'icsea': 1020}
# tensor(4) {'name': 'LAKE JOONDALUP BAPTIST COLLEGE', 'lat': -31.73747504, 'lon': 115.7614206, 'num_student': 1468, 'atar': 77.25, 'icsea': 1105}
# tensor(4) {'name': 'LANGFORD ISLAMIC COLLEGE', 'lat': -32.04605574, 'lon': 115.9371583, 'num_student': 1043, 'atar': 75.9, 'icsea': 1098}
# tensor(4) {'name': 'LEEMING SENIOR HIGH SCHOOL', 'lat': -32.07467304, 'lon': 115.8564902, 'num_student': 1091, 'atar': 75.6, 'icsea': 1071}
# tensor(4) {'name': 'LESMURDIE SENIOR HIGH SCHOOL', 'lat': -32.01252075, 'lon': 116.0516431, 'num_student': 1057, 'atar': 78.95, 'icsea': 1032}
# tensor(4) {'name': 'LYNWOOD SENIOR HIGH SCHOOL', 'lat': -32.04190909, 'lon': 115.9161296, 'num_student': 1417, 'atar': 74.35, 'icsea': 980}
# tensor(4) {'name': 'MANDURAH CATHOLIC COLLEGE', 'lat': -32.54895945, 'lon': 115.738286, 'num_student': 1676, 'atar': 84.5, 'icsea': 1040}
# tensor(4) {'name': 'MARGARET RIVER SENIOR HIGH SCHOOL', 'lat': -33.95431827, 'lon': 115.0746714, 'num_student': 1100, 'atar': 82.35, 'icsea': 1037}
# tensor(4) {'name': 'MELVILLE SENIOR HIGH SCHOOL', 'lat': -32.04631125, 'lon': 115.8054613, 'num_student': 1402, 'atar': 80.35, 'icsea': 1065}
# tensor(4) {'name': 'MERCY COLLEGE', 'lat': -31.84725114, 'lon': 115.8575544, 'num_student': 1620, 'atar': 82.5, 'icsea': 1010}
# tensor(4) {'name': "METHODIST LADIES' COLLEGE", 'lat': -31.98701169, 'lon': 115.7755403, 'num_student': 1019, 'atar': 90.55, 'icsea': 1150}
# tensor(4) {'name': 'NAGLE CATHOLIC COLLEGE', 'lat': -28.77776964, 'lon': 114.6099931, 'num_student': 1089, 'atar': 77.05, 'icsea': 1018}
# tensor(4) {'name': 'OCEAN REEF SENIOR HIGH SCHOOL', 'lat': -31.75879833, 'lon': 115.7389749, 'num_student': 1234, 'atar': 76.35, 'icsea': 1052}
# tensor(4) {'name': 'PERTH COLLEGE', 'lat': -31.93117853, 'lon': 115.8754809, 'num_student': 1028, 'atar': 89.4, 'icsea': 1153}
# tensor(4) {'name': 'PERTH MODERN SCHOOL', 'lat': -31.94506602, 'lon': 115.8363958, 'num_student': 1428, 'atar': 97.55, 'icsea': 1239}
# tensor(4) {'name': 'PETER MOYES ANGLICAN COMMUNITY SCHOOL', 'lat': -31.67541576, 'lon': 115.7075982, 'num_student': 1347, 'atar': 81.05, 'icsea': 1073}
# tensor(4) {'name': 'PRENDIVILLE CATHOLIC COLLEGE', 'lat': -31.75468355, 'lon': 115.7396844, 'num_student': 1133, 'atar': 80.45, 'icsea': 1077}
# tensor(4) {'name': 'PRESBYTERIAN LADIES COLLEGE', 'lat': -31.993592, 'lon': 115.764906, 'num_student': 1027, 'atar': 89.2, 'icsea': 1111}
# tensor(4) {'name': 'QUINNS BAPTIST COLLEGE', 'lat': -31.67618587, 'lon': 115.7101964, 'num_student': 1183, 'atar': 66.9, 'icsea': 1062}
# tensor(4) {'name': 'SACRED HEART COLLEGE', 'lat': -31.82737166, 'lon': 115.74657, 'num_student': 1425, 'atar': 87.6, 'icsea': 1109}
# tensor(4) {'name': 'SANTA MARIA COLLEGE', 'lat': -32.018614, 'lon': 115.795823, 'num_student': 1297, 'atar': 89.35, 'icsea': 1117}
# tensor(4) {'name': 'SCOTCH COLLEGE', 'lat': -31.98113329, 'lon': 115.7731945, 'num_student': 1418, 'atar': 85.35, 'icsea': 1165}
# tensor(4) {'name': "ST HILDA'S ANGLICAN SCHOOL FOR GIRLS", 'lat': -32.005047, 'lon': 115.767812, 'num_student': 1109, 'atar': 92.7, 'icsea': 1197}
# tensor(4) {'name': "ST MARK'S ANGLICAN COMMUNITY SCHOOL", 'lat': -31.79848743, 'lon': 115.7428728, 'num_student': 1722, 'atar': 80.8, 'icsea': 1119}
# tensor(4) {'name': 'ST MARY MACKILLOP COLLEGE', 'lat': -33.66260748, 'lon': 115.3302509, 'num_student': 1458, 'atar': 79.3, 'icsea': 1045}
# tensor(4) {'name': "ST MARY'S ANGLICAN GIRLS' SCHOOL", 'lat': -31.87697112, 'lon': 115.766244, 'num_student': 1452, 'atar': 90.3, 'icsea': 1158}
# tensor(4) {'name': 'SWAN CHRISTIAN COLLEGE', 'lat': -31.85830659, 'lon': 116.0117533, 'num_student': 1482, 'atar': 74.65, 'icsea': 1064}
# tensor(4) {'name': 'SWAN VALLEY ANGLICAN COMMUNITY SCHOOL', 'lat': -31.79434482, 'lon': 115.9854516, 'num_student': 1148, 'atar': 81.25, 'icsea': 1045}
# tensor(4) {'name': 'THORNLIE SENIOR HIGH SCHOOL', 'lat': -32.06627622, 'lon': 115.959641, 'num_student': 1164, 'atar': 65.35, 'icsea': 976}
# tensor(4) {'name': 'TRINITY COLLEGE', 'lat': -31.96013472, 'lon': 115.8825766, 'num_student': 1216, 'atar': 82.85, 'icsea': 1113}
# tensor(4) {'name': 'URSULA FRAYNE CATHOLIC COLLEGE', 'lat': -31.97297817, 'lon': 115.8990335, 'num_student': 1406, 'atar': 83.15, 'icsea': 1097}
# tensor(4) {'name': 'WESLEY COLLEGE', 'lat': -31.97995555, 'lon': 115.865934, 'num_student': 1244, 'atar': 83.9, 'icsea': 1143}
# tensor(4) {'name': 'WOODVALE SECONDARY COLLEGE', 'lat': -31.79154969, 'lon': 115.7994712, 'num_student': 1436, 'atar': 77.65, 'icsea': 1064}
# /opt/anaconda3/lib/python3.11/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
